# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("archive/AWCustomers.csv")

# %%
data.head()
# Out:
#    CustomerID Title FirstName MiddleName  LastName Suffix  \
# 0       21173   NaN      Chad          C      Yuan    NaN
# 1       13249   NaN      Ryan        NaN     Perry    NaN
# 2       29350   NaN     Julia        NaN  Thompson    NaN
# 3       13503   NaN  Theodore        NaN     Gomez    NaN
# 4       22803   NaN  Marshall          J      Shan    NaN
#
#              AddressLine1 AddressLine2         City    StateProvinceName  ...  \
# 0      7090 C. Mount Hood          NaN   Wollongong      New South Wales  ...
# 1     3651 Willow Lake Rd          NaN      Shawnee     British Columbia  ...
# 2  1774 Tice Valley Blvd.          NaN  West Covina           California  ...
# 3         2103 Baldwin Dr          NaN    Liverpool              England  ...
# 4         Am Gallberg 234          NaN        Werne  Nordrhein-Westfalen  ...
#
#          Education      Occupation Gender MaritalStatus HomeOwnerFlag  \
# 0        Bachelors        Clerical      M             M             1
# ...

# %%
data["Title"].value_counts()
# Out:
# Title
# Mr.     52
# Ms.     41
# Sr.      5
# Mrs.     2
# Ms       1
# Name: count, dtype: int64

# %%
data["Suffix"].value_counts()
# Out:
# Suffix
# Jr.    3
# Name: count, dtype: int64

# %%
len(data)
# Out:
# 18361

# %%
data["AddressLine1"].value_counts()
# Out:
# AddressLine1
# Attaché de Presse                  17
# Midi-Couleurs                      15
# 88, avenue de l´ Union Centrale    12
# 6, route de Marseille              12
# Im Himmelsweg 89                   10
#                                    ..
# 3085 Curtis Drive                   1
# 8869 Climbing Vine Court            1
# 8881, rue Villedo                   1
# Nonnendamm 6500                     1
# 3866 Mt. Everest Court              1
# Name: count, Length: 12742, dtype: int64

# %%
data["AddressLine2"].value_counts()
# Out:
# AddressLine2
# Verkaufsabteilung        34
# Einkaufsabteilung        16
# # 1                       8
# # 2                       7
# Kreditorenbuchhaltung     7
#                          ..
# # 1117                    1
# # 123                     1
# # 108                     1
# Unit D7                   1
# # 22                      1
# Name: count, Length: 166, dtype: int64

# %%
data["AddressLine1"].isna().sum()
# Out:
# np.int64(0)

# %%
data["AddressLine2"].isna().sum()
# Out:
# np.int64(18050)

# %%
data["City"].value_counts()
# Out:
# City
# London              420
# Paris               384
# Burien              212
# Beaverton           210
# Concord             210
#                    ...
# Cheyenne              1
# Byron                 1
# Carrollton            1
# City Of Commerce      1
# Chehalis              1
# Name: count, Length: 269, dtype: int64

# %%
data["City"].isna().sum()
# Out:
# np.int64(0)

# %%
cols = data.columns

# %%
for col in cols:
    print("Unique Values in",col)
    print(data[col].value_counts())
    print()
    print("Numebr of null values in",col)
    print(data[col].isna().sum())
    print()
    print()
# Out:
# Unique Values in CustomerID
# CustomerID
# 21647    2
# 23192    2
# 26829    2
# 13385    2
# 24334    2
#         ..
# 27615    1
# 23310    1
# 19682    1
# 22875    1
# 16676    1
# Name: count, Length: 18355, dtype: int64
#
# Numebr of null values in CustomerID
# 0
#
#
# Unique Values in Title
# Title
# Mr.     52
# Ms.     41
# Sr.      5
# Mrs.     2
# Ms       1
# Name: count, dtype: int64
#
# Numebr of null values in Title
# 18260
#
#
# Unique Values in FirstName
# FirstName
# Katherine    97
# Marcus       96
# Richard      94
# Morgan       93
# Lucas        93
#              ..
# Rob           1
# Alícia        1
# Petr          1
# Vadim         1
# Masato        1
# Name: count, Length: 670, dtype: int64
#
# Numebr of null values in FirstName
# 0
#
#
# Unique Values in MiddleName
# MiddleName
# A             1287
# L             1247
# M             1113
# J              973
# C              919
# E              714
# R              670
# D              567
# ...

# %%
col_to_drop = ["Title", "MiddleName", "Suffix", "AddressLine2"]

# %%
data["LastUpdated"].value_counts()
# Out:
# LastUpdated
# 2017-03-06    18291
# 2017-03-07       70
# Name: count, dtype: int64

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data["CustomerID"].value_counts()
# Out:
# CustomerID
# 21647    2
# 23192    2
# 26829    2
# 13385    2
# 24334    2
#         ..
# 27615    1
# 23310    1
# 19682    1
# 22875    1
# 16676    1
# Name: count, Length: 18355, dtype: int64

# %%
data = data.drop(columns = col_to_drop)

# %%
data.head()
# Out:
#    CustomerID FirstName  LastName            AddressLine1         City  \
# 0       21173      Chad      Yuan      7090 C. Mount Hood   Wollongong
# 1       13249      Ryan     Perry     3651 Willow Lake Rd      Shawnee
# 2       29350     Julia  Thompson  1774 Tice Valley Blvd.  West Covina
# 3       13503  Theodore     Gomez         2103 Baldwin Dr    Liverpool
# 4       22803  Marshall      Shan         Am Gallberg 234        Werne
#
#      StateProvinceName CountryRegionName PostalCode          PhoneNumber  \
# 0      New South Wales         Australia       2500  1 (11) 500 555-0115
# 1     British Columbia            Canada    V9B 2C3         787-555-0136
# 2           California     United States      91791         120-555-0111
# 3              England    United Kingdom     L4 4HB  1 (11) 500 555-0167
# 4  Nordrhein-Westfalen           Germany      59368  1 (11) 500 555-0113
#
#     BirthDate        Education      Occupation Gender MaritalStatus  \
# ...

# %%
data = data.drop(columns = ["LastUpdated"])

# %%
data.head()
# Out:
#    CustomerID FirstName  LastName            AddressLine1         City  \
# 0       21173      Chad      Yuan      7090 C. Mount Hood   Wollongong
# 1       13249      Ryan     Perry     3651 Willow Lake Rd      Shawnee
# 2       29350     Julia  Thompson  1774 Tice Valley Blvd.  West Covina
# 3       13503  Theodore     Gomez         2103 Baldwin Dr    Liverpool
# 4       22803  Marshall      Shan         Am Gallberg 234        Werne
#
#      StateProvinceName CountryRegionName PostalCode          PhoneNumber  \
# 0      New South Wales         Australia       2500  1 (11) 500 555-0115
# 1     British Columbia            Canada    V9B 2C3         787-555-0136
# 2           California     United States      91791         120-555-0111
# 3              England    United Kingdom     L4 4HB  1 (11) 500 555-0167
# 4  Nordrhein-Westfalen           Germany      59368  1 (11) 500 555-0113
#
#     BirthDate        Education      Occupation Gender MaritalStatus  \
# ...

# %%
data = data.drop(columns = ["PhoneNumber"])

# %%
data.head()
# Out:
#    CustomerID FirstName  LastName            AddressLine1         City  \
# 0       21173      Chad      Yuan      7090 C. Mount Hood   Wollongong
# 1       13249      Ryan     Perry     3651 Willow Lake Rd      Shawnee
# 2       29350     Julia  Thompson  1774 Tice Valley Blvd.  West Covina
# 3       13503  Theodore     Gomez         2103 Baldwin Dr    Liverpool
# 4       22803  Marshall      Shan         Am Gallberg 234        Werne
#
#      StateProvinceName CountryRegionName PostalCode   BirthDate  \
# 0      New South Wales         Australia       2500  1987-11-13
# 1     British Columbia            Canada    V9B 2C3  1972-07-21
# 2           California     United States      91791  1985-11-09
# 3              England    United Kingdom     L4 4HB  1977-10-18
# 4  Nordrhein-Westfalen           Germany      59368  1975-02-05
#
#          Education      Occupation Gender MaritalStatus  HomeOwnerFlag  \
# 0        Bachelors        Clerical      M             M              1
# ...

# %%
data["CustomerID"].value_counts()
# Out:
# CustomerID
# 21647    2
# 23192    2
# 26829    2
# 13385    2
# 24334    2
#         ..
# 27615    1
# 23310    1
# 19682    1
# 22875    1
# 16676    1
# Name: count, Length: 18355, dtype: int64

# %%
data[data["CustomerID"] == 23192]
# Out:
#     CustomerID FirstName LastName           AddressLine1       City  \
# 59       23192     Emily   Garcia  8180 Loveridge Circle  Palo Alto
# 60       23192     Emily   Garcia  8180 Loveridge Circle  Palo Alto
#
#    StateProvinceName CountryRegionName PostalCode   BirthDate  Education  \
# 59        California     United States      94303  1985-04-08  Bachelors
# 60        California     United States      94303  1985-04-08  Bachelors
#
#    Occupation Gender MaritalStatus  HomeOwnerFlag  NumberCarsOwned  \
# 59   Clerical      F             M              1                2
# 60   Clerical      F             M              1                2
#
#     NumberChildrenAtHome  TotalChildren  YearlyIncome
# 59                     0              1         82359
# 60                     0              1         82359

# %%
# there are some repeated rows which we need to eliminate will do later

# %%
data.isna().sum()
# Out:
# CustomerID              0
# FirstName               0
# LastName                0
# AddressLine1            0
# City                    0
# StateProvinceName       0
# CountryRegionName       0
# PostalCode              0
# BirthDate               0
# Education               0
# Occupation              0
# Gender                  0
# MaritalStatus           0
# HomeOwnerFlag           0
# NumberCarsOwned         0
# NumberChildrenAtHome    0
# TotalChildren           0
# YearlyIncome            0
# dtype: int64

# %%
len(data)
# Out:
# 18361

# %%
data = data.drop_duplicates()
len(data)
# Out:
# 18357

# %%
# now storing a cpopy of the dataset so far and then exploring
df =  data.copy()

# %%
# backup -> df

# %%
col = ["CustomerID", "FirstName", "LastName", "AddressLine1"]
data = data.drop(columns = col)

# %%
data.head()
# Out:
#           City    StateProvinceName CountryRegionName PostalCode   BirthDate  \
# 0   Wollongong      New South Wales         Australia       2500  1987-11-13
# 1      Shawnee     British Columbia            Canada    V9B 2C3  1972-07-21
# 2  West Covina           California     United States      91791  1985-11-09
# 3    Liverpool              England    United Kingdom     L4 4HB  1977-10-18
# 4        Werne  Nordrhein-Westfalen           Germany      59368  1975-02-05
#
#          Education      Occupation Gender MaritalStatus  HomeOwnerFlag  \
# 0        Bachelors        Clerical      M             M              1
# 1  Partial College        Clerical      M             M              1
# 2        Bachelors        Clerical      F             S              0
# 3  Partial College  Skilled Manual      M             M              1
# 4  Partial College  Skilled Manual      M             S              1
#
#    NumberCarsOwned  NumberChildrenAtHome  TotalChildren  YearlyIncome
# ...

# %%
from datetime import date
years = []
for dates in data["BirthDate"]:
    tt = (int)(date.today().year) - (int)(dates[0:4])
    years.append(tt)

# %%
years
# Out:
# [38,
#  53,
#  40,
#  48,
#  50,
#  50,
#  54,
#  28,
#  49,
#  49,
#  27,
#  44,
#  41,
#  65,
#  34,
#  54,
#  60,
#  32,
#  44,
#  62,
#  45,
#  49,
#  64,
#  29,
#  32,
#  36,
#  35,
#  59,
#  42,
#  39,
#  41,
#  45,
#  47,
#  47,
#  28,
#  37,
#  35,
#  29,
#  38,
#  42,
#  40,
#  43,
#  39,
#  37,
#  41,
#  51,
#  43,
#  54,
#  40,
#  36,
#  30,
#  38,
#  41,
#  31,
#  39,
#  27,
#  59,
#  32,
#  40,
#  60,
#  45,
#  59,
#  68,
#  40,
#  39,
#  41,
#  26,
#  54,
#  47,
#  55,
#  29,
#  48,
#  29,
#  38,
#  49,
#  43,
#  45,
#  54,
#  37,
#  56,
#  30,
#  58,
#  68,
#  59,
#  36,
#  31,
#  53,
#  44,
#  58,
#  49,
#  41,
#  38,
#  48,
#  32,
#  33,
#  40,
#  65,
#  44,
#  67,
#  28,
#  62,
#  62,
#  31,
#  38,
#  37,
#  65,
#  39,
#  37,
#  29,
#  49,
#  28,
#  39,
#  57,
#  42,
#  52,
#  52,
#  34,
#  32,
#  63,
#  45,
#  59,
#  40,
#  35,
#  41,
#  28,
#  42,
#  50,
#  43,
#  49,
#  34,
#  53,
#  47,
#  33,
#  56,
#  65,
#  38,
#  66,
#  29,
#  44,
#  36,
#  49,
#  45,
# ...
